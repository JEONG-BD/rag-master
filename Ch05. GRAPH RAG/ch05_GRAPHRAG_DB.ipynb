# %%
from pathlib import Path 

working_dir = Path("working_directory")
working_dir.mkdir(parents=True, exist_ok=True)

# %%
# !graphrag index --root ./working_directory --method standard

# %%
# !graphrag query   --root ./working_directory --method local "채권의 전환성 개념이 각 챕터들에서 어떻게 소개되어 있나요?"
# Out:
# 17:53:16 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 17:53:16 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# 제공된 자료를 기반으로 볼 때, 해당 책의 각 챕터에서 **채권의 전환성(bond convertibility)이라는 특정 개념 자체가 소개되거나 그 메커니즘에 대해 자세히 설명하고 있지는 않습니다.**
#
# 다만, 자료는 해당 투자 서적의 목차와 내용을 제공하며, 여러 종류의 다양한 채권에 대한 정보를 다루고 있습니다. 따라서 이 서적이 어떤 유형의 금융 상품을 소개하는지는 설명 드릴 수 있습니다.
#
# 다음은 해당 저서가 다루는 투자 및 채권 관련 정보의 개요입니다.
#
# ### 『돈을 버는 방법(How to Invest Money)』의 구성 및 내용
#
# 제시된 자료에 따르면, 이 책은 투자에 대한 일반적인 원칙과 더불어 각 종류별 금융 상품에 대해 심도 있게 다루고 있습니다.
#
# *   **투자 일반 원칙 (Chapter I):** 책의 도입부로서, 투자에 대한 광범위한 이론적 배경을 제시합니다. 이 부분은 당대의 부의 축적 문제와 투자 문제를 다루는 일반적인 관점을 독자들에게 제공합니다 [Data: Sources (0)].
# ...

# %%
# !graphrag query   --root ./working_directory --method global "산업 채권 평가시 순 유동 자산을 어떻게 분석해야 하나요?"
# Out:
# 17:57:54 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 17:57:54 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# I am sorry but I am unable to answer this question given the provided data.
